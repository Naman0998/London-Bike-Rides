# %%
#Importing libraries
import pandas as pd
import zipfile

# %%
#Extracting files from zipfile
zip = 'archive (1).zip'
with zipfile.ZipFile(zip,'r') as file:
  file.extractall()

# %%
#Loading the Dataset
bikes = pd.read_csv('london_merged.csv')
bikes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
bikes.shape
# Out:
# (17414, 10)

# %%
bikes.head()
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %%
#Checking Unique Values for weather
bikes.weather_code.value_counts()
# Out:
# 1.0     6150
# 2.0     4034
# 3.0     3551
# 7.0     2141
# 4.0     1464
# 26.0      60
# 10.0      14
# Name: weather_code, dtype: int64

# %%
#Checking Unique Values for weather
bikes.season.value_counts()
# Out:
# 0.0    4394
# 1.0    4387
# 3.0    4330
# 2.0    4303
# Name: season, dtype: int64

# %%
#Checking columns
bikes.columns
# Out:
# Index(['timestamp', 'cnt', 't1', 't2', 'hum', 'wind_speed', 'weather_code',
#        'is_holiday', 'is_weekend', 'season'],
#       dtype='object')

# %%
#Chaning Column names according to need
new_cols = {
    'timestamp' : 'time',
    'cnt' : 'count',
    't1':'temp',
    't2':'temp_feelslike',
    'hum':'humidity_percentage',
    'wind_speed':'wind_speed_kph',
    'weather_code':'weather',
    'is_holiday':'is_holiday',
    'is_weekend':'is_weekend',
    'season':'season'
}
bikes.rename(new_cols,axis = 1, inplace = True)

#Changing Season codes to actual season names
season_dict = {
    '0.0':'Spring',
    '1.0':'Summer',
    '2.0':'Autumn',
    '3.0':'Winter'
}
bikes.season = bikes.season.astype('str')
bikes.season = bikes.season.map(season_dict)

#Changing Weather codes to actual weather names
weather_dict = {
    '1.0':'Clear',
    '2.0':'Scattered clouds',
    '3.0':'Broken clouds',
    '4.0':'Cloudy',
    '7.0':'Rain',
    '10.0':'Rain with thunderstorm',
    '26.0':'Snowfall'
}
bikes.weather = bikes.weather.astype('str')
bikes.weather = bikes.weather.map(weather_dict)

# %%
#Changing Humidity in actual Humidity Percentage
bikes.humidity_percentage = bikes.humidity_percentage/100

# %%
bikes.head()
# Out:
#                   time  count  temp  temp_feelslike  humidity_percentage  \
# 0  2015-01-04 00:00:00    182   3.0             2.0              0.00930
# 1  2015-01-04 01:00:00    138   3.0             2.5              0.00930
# 2  2015-01-04 02:00:00    134   2.5             2.5              0.00965
# 3  2015-01-04 03:00:00     72   2.0             2.0              0.01000
# 4  2015-01-04 04:00:00     47   2.0             0.0              0.00930
#
#    wind_speed_kph        weather  is_holiday  is_weekend  season
# 0             6.0  Broken clouds         0.0         1.0  Winter
# 1             5.0          Clear         0.0         1.0  Winter
# 2             0.0          Clear         0.0         1.0  Winter
# 3             0.0          Clear         0.0         1.0  Winter
# 4             6.5          Clear         0.0         1.0  Winter

# %%
# writing the final dataframe to an excel file that we will use in our Tableau visualisations. The file will be the 'london_bikes_final.xlsx' file and the sheet name is 'Data'
bikes.to_excel('london_bikes_final.xlsx', sheet_name='Data')
